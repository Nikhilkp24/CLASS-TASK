# %%
import pandas as pd

# %%
#read data from mysql
mydb = connection.connect(host='localhost',user='root',password='2408',database = 'pdtask',use_pure=True)

# %%
import mysql.connector as connection
data1 = pd.read_sql('select * from fitbit',conn)
data1.head(5)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0                2.57                      0.46
# 1                         0                6.92                      0.73
# 2                         0                4.66                      0.16
# 3                         0                3.19                      0.79
# 4                         0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
#read data from mongodb
import pymongo
client = pymongo.MongoClient("mongodb+srv://nikhilkp24:2408@nikhilkp2419.lrhpq.mongodb.net/?retryWrites=true&w=majority")
db = client['pd_task']
coll = db['fitbit']
x = coll.find()
for data in x:
    print(data)
# Out:
# {'_id': ObjectId('62e92cae8f24924d9ca73036'), 'Id': 1503960366, 'ActivityDate': '3/25/2016', 'TotalSteps': 11004, 'TotalDistance': 7.1100001335144, 'TrackerDistance': 7.1100001335144, 'LoggedActivitiesDistance': 0.0, 'VeryActiveDistance': 2.5699999332428, 'ModeratelyActiveDistance': 0.46000000834465, 'LightActiveDistance': 4.07000017166138, 'SedentaryActiveDistance': 0.0, 'VeryActiveMinutes': 33, 'FairlyActiveMinutes': 12, 'LightlyActiveMinutes': 205, 'SedentaryMinutes': 804, 'Calories': 1819}
# ...

# %%
df1 = pd.read_csv(r'FitBit data.csv')

# %%
#Read this dataset in pandas
df1
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df1.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
#3. convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format
df1['ActivityDate'] = pd.to_datetime(df1['ActivityDate'])
df1.dtypes
# Out:
# Id                                   int64
# ActivityDate                datetime64[ns]
# TotalSteps                           int64
# TotalDistance                      float64
# TrackerDistance                    float64
# LoggedActivitiesDistance           float64
# VeryActiveDistance                 float64
# ModeratelyActiveDistance           float64
# LightActiveDistance                float64
# SedentaryActiveDistance            float64
# VeryActiveMinutes                    int64
# FairlyActiveMinutes                  int64
# LightlyActiveMinutes                 int64
# SedentaryMinutes                     int64
# Calories                             int64
# dtype: object

# %%
#4 . Find out in this data that how many unique id's we have 
df1['Id'].nunique()
# Out:
# 35

# %%
#5 . which id is one of the active id that you have in whole dataset 
df1.groupby('Id')['Calories'].sum().idxmax()
# Out:
# 4020332650

# %%
#6 . how many of them have not logged there activity find out in terms of number of ids 
len(df1[df1['Calories']>2000]['Id'].unique())
# Out:
# 30

# %%
df1.groupby('Id')['LoggedActivitiesDistance'].sum().apply(lambda x:x<1).value_counts()
# Out:
# True     30
# False     5
# Name: LoggedActivitiesDistance, dtype: int64

# %%
#7 . Find out who is the laziest person id that we have in dataset 
df1.groupby('Id')['Calories'].sum().idxmin()
# Out:
# 4388161847

# %%
#8 . Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset 
len(df1[df1['Calories']>2500]['Id'].unique())
# Out:
# 17

# %%
#9. how many person are not a regular person with respect to activity try to find out those 
df1["TotalActiveMinutes"]=(df1['VeryActiveMinutes']+df1['FairlyActiveMinutes'] +df1['LightlyActiveMinutes'])
len(df1[df1["TotalActiveMinutes"]==0]['Id'].unique())
# Out:
# 15

# %%
#10 . who is the thired most active person in this dataset find out those in pandas and in sql both .
df1.groupby('Id')['VeryActiveMinutes'].sum().sort_values( ascending=False)[2:3]
# Out:
# Id
# 8877689391    802
# Name: VeryActiveMinutes, dtype: int64

# %%
#10 sql query

select id, sum(VeryActiveMinutes) from fitbit
 group by Id ORDER BY sum(VeryActiveMinutes)
 DESC limit 1 offset 2;

# %%
#11. who is the 5th most laziest person avilable in dataset find it out 
df1.groupby('Id')['SedentaryMinutes'].sum().sort_values(ascending=True)[4:5]
# Out:
# Id
# 6962181067    8488
# Name: SedentaryMinutes, dtype: int64

# %%
#12 . what is a totla acumulative calories burn for a person find out 
df1.groupby('Id')['Calories'].sum()
# Out:
# Id
# 1503960366    34128
# 1624580081    25705
# 1644430081    29164
# 1844505072    19391
# 1927972279    27048
# 2022484408    29704
# 2026352035    16266
# 2320127002    18385
# 2347167796    30320
# 2873212765    20349
# 2891001357    18187
# 3372868164    18603
# 3977333714    16777
# 4020332650    98412
# 4057192912    60913
# 4319703577    23931
# 4388161847    14442
# 4445114986    31617
# 4558609924    21962
# 4702921684    42322
# 5553957443    21630
# 5577150313    36303
# 6117666160    20993
# 6290855005    21656
# 6391747486    15868
# 6775888955    24523
# 6962181067    29249
# 7007744171    31525
# 7086361926    26124
# 8053475328    31825
# 8253242879    17556
# 8378563200    40274
# 8583815059    19130
# 8792009665    24884
# 8877689391    41414
# Name: Calories, dtype: int64
